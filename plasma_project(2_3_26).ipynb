# %% [markdown]
# <a href="https://colab.research.google.com/github/zephyrsab/all-contributors/blob/master/plasma_project(2_3_26).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspedas
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 99.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.5/202.5 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 83.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 88.3 MB/s eta 0:00:00
# ...

# %%
from pyspedas.projects.mms import fgm , fpi
from pyspedas import tplot, tplot_names, tlimit
from pyspedas import tdpwrspc
import pyspedas
import numpy as np

# %%
fgm_vars = fgm(trange=['2015-10-07/11:40:00', '2015-10-07/12:00:00'], probe= "1" , time_clip=True)
# Out:
# 02-Mar-26 15:07:16: Loading files for group: probe: 1, drate: srvy, level: l2, datatype: , after sorting and filtering:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 02-Mar-26 15:07:16: pydata/mms1/fgm/srvy/l2/2015/10/mms1_fgm_srvy_l2_20151007_v4.18.0.cdf
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
tplot_names()
# Out:
# 0 : Epoch
# 1 : mms1_fgm_b_gse_srvy_l2
# 2 : mms1_fgm_b_gsm_srvy_l2
# 3 : mms1_fgm_b_dmpa_srvy_l2
# 4 : mms1_fgm_b_bcs_srvy_l2
# 5 : mms1_fgm_flag_srvy_l2
# 6 : Epoch_state
# 7 : mms1_fgm_hirange_srvy_l2
# 8 : mms1_fgm_bdeltahalf_srvy_l2
# 9 : mms1_fgm_stemp_srvy_l2
# 10 : mms1_fgm_etemp_srvy_l2
# 11 : mms1_fgm_mode_srvy_l2
# 12 : mms1_fgm_b_dmpa_srvy_l2_bvec
# 13 : mms1_fgm_b_dmpa_srvy_l2_btot
# 14 : mms1_fgm_b_gse_srvy_l2_bvec
# 15 : mms1_fgm_b_gse_srvy_l2_btot
# 16 : mms1_fgm_b_gsm_srvy_l2_bvec
# 17 : mms1_fgm_b_gsm_srvy_l2_btot
# 18 : mms1_fgm_b_bcs_srvy_l2_bvec
# 19 : mms1_fgm_b_bcs_srvy_l2_btot
# 20 : Epoch_plus_var
# 21 : Epoch_minus_var
# 22 : mms1_dis_errorflags_fast_moms
# 23 : mms1_dis_compressionloss_fast_moms
# 24 : mms1_dis_startdelphi_count_fast
# 25 : mms1_dis_startdelphi_angle_fast
# 26 : mms1_dis_energyspectr_px_fast
# 27 : mms1_dis_energyspectr_mx_fast
# 28 : mms1_dis_energyspectr_py_fast
# 29 : mms1_dis_energyspectr_my_fast
# 30 : mms1_dis_energyspectr_pz_fast
# ...

# %%
tlimit(['2015-10-07/11:44:00', '2015-10-07/11:47:00'])

# %%
tplot(['mms1_fgm_b_gse_srvy_l2_bvec , mms1_fgm_b_gse_srvy_l2_btot'])
# Out:
# 02-Mar-26 15:07:22: wildcard_expand: No match found for ,

# %%
fpi_vars = fpi(trange=['2015-10-07/11:40:00', '2015-10-07/12:00:00'], probe= "1" , time_clip=True, datatype='dis-moms')
# Out:
# 02-Mar-26 15:07:23: Loading files for group: probe: 1, drate: fast, level: l2, datatype: dis-moms, after sorting and filtering:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 02-Mar-26 15:07:23: pydata/mms1/fpi/fast/l2/dis-moms/2015/10/mms1_fpi_fast_l2_dis-moms_20151007100000_v3.4.0.cdf
# 02-Mar-26 15:07:23: The name mms1_dis_pitchangdist_lowen_fast is currently not in pyspedas
# 02-Mar-26 15:07:23: The name mms1_dis_pitchangdist_miden_fast is currently not in pyspedas
# 02-Mar-26 15:07:23: The name mms1_dis_pitchangdist_highen_fast is currently not in pyspedas
# ...

# %%
tlimit(['2015-10-07/11:40:00', '2015-10-07/11:50:00'])

# %%
tplot_names()
# Out:
# 0 : Epoch
# 1 : mms1_fgm_b_gse_srvy_l2
# 2 : mms1_fgm_b_gsm_srvy_l2
# 3 : mms1_fgm_b_dmpa_srvy_l2
# 4 : mms1_fgm_b_bcs_srvy_l2
# 5 : mms1_fgm_flag_srvy_l2
# 6 : Epoch_state
# 7 : mms1_fgm_hirange_srvy_l2
# 8 : mms1_fgm_bdeltahalf_srvy_l2
# 9 : mms1_fgm_stemp_srvy_l2
# 10 : mms1_fgm_etemp_srvy_l2
# 11 : mms1_fgm_mode_srvy_l2
# 12 : mms1_fgm_b_dmpa_srvy_l2_bvec
# 13 : mms1_fgm_b_dmpa_srvy_l2_btot
# 14 : mms1_fgm_b_gse_srvy_l2_bvec
# 15 : mms1_fgm_b_gse_srvy_l2_btot
# 16 : mms1_fgm_b_gsm_srvy_l2_bvec
# 17 : mms1_fgm_b_gsm_srvy_l2_btot
# 18 : mms1_fgm_b_bcs_srvy_l2_bvec
# 19 : mms1_fgm_b_bcs_srvy_l2_btot
# 20 : Epoch_plus_var
# 21 : Epoch_minus_var
# 22 : mms1_dis_errorflags_fast_moms
# 23 : mms1_dis_compressionloss_fast_moms
# 24 : mms1_dis_startdelphi_count_fast
# 25 : mms1_dis_startdelphi_angle_fast
# 26 : mms1_dis_energyspectr_px_fast
# 27 : mms1_dis_energyspectr_mx_fast
# 28 : mms1_dis_energyspectr_py_fast
# 29 : mms1_dis_energyspectr_my_fast
# 30 : mms1_dis_energyspectr_pz_fast
# ...

# %%
tplot(['mms1_dis_bulkv_gse_fast','mms1_dis_numberdensity_fast'])
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2197: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   return self._math_expression.parseString(toks[0][1:-1], parseAll=True)
# /usr/local/lib/python3.12/dist-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()

# %%
metadata = pyspedas.get_data('mms1_dis_numberdensity_fast', metadata=True)

# %%
print(metadata)
# Out:
# {'CDF': {'VATT': {'CATDESC': 'MMS1 FPI/DIS ion number density during this survey', 'DELTA_PLUS_VAR': 'mms1_dis_numberdensity_err_fast', 'DELTA_MINUS_VAR': 'mms1_dis_numberdensity_err_fast', 'DEPEND_0': 'Epoch', 'DISPLAY_TYPE': 'time_series', 'FIELDNAM': 'MMS1 FPI/DIS number density', 'FILLVAL': np.float32(-1e+31), 'FORMAT': 'E12.2', 'LABLAXIS': 'N', 'SCALETYP': 'linear', 'SI_CONVERSION': '1e6>m^-3', 'UNITS': 'cm^-3', 'VALIDMIN': np.float32(0.0), 'VALIDMAX': np.float32(100000.0), 'VAR_TYPE': 'data'}, 'GATT': {'Project': ['STP>Solar-Terrestrial Physics'], 'Source_name': ['MMS1>MMS Satellite Number 1'], 'Discipline': ['Space Physics>Magnetospheric Science'], 'Data_type': ['fast_l2_dis-moms'], 'Descriptor': ['DIS>Dual Ion Spectrometers'], 'File_naming_convention': ['source_descriptor_datatype_yyyyMMddHHmmss'], 'Data_version': ['3.4.0'], 'PI_name': ['J. Burch, B. Giles'], 'PI_affiliation': ['SwRI, GSFC'], 'TEXT': ['FPI usually operates in Fast Survey (FS) Mode in the MMS Region Of Interes
# ...

# %%
get_data
